# %%
import pandas as pd
import os

# %%
folder_directory = "C:/Users/John Xu/Desktop/NYC_Taxi_Trips/data/Data/"

# %%
data_list = os.listdir(folder_directory)

# %%
data_list
# Out:
# ['Green Taxi Data 2019-1.csv',
#  'Green Taxi Data 2019-2.csv',
#  'Green Taxi Data 2019-3.csv',
#  'Green Taxi Data 2019-4.csv',
#  'Green Taxi Data 2019-5.csv',
#  'Green Taxi Data 2019-6.csv']

# %%
directory_list = [os.path.join(folder_directory, data_name) for data_name in data_list]

# %%
directory_list
# Out:
# ['C:/Users/John Xu/Desktop/NYC_Taxi_Trips/data/Data/Green Taxi Data 2019-1.csv',
#  'C:/Users/John Xu/Desktop/NYC_Taxi_Trips/data/Data/Green Taxi Data 2019-2.csv',
#  'C:/Users/John Xu/Desktop/NYC_Taxi_Trips/data/Data/Green Taxi Data 2019-3.csv',
#  'C:/Users/John Xu/Desktop/NYC_Taxi_Trips/data/Data/Green Taxi Data 2019-4.csv',
#  'C:/Users/John Xu/Desktop/NYC_Taxi_Trips/data/Data/Green Taxi Data 2019-5.csv',
#  'C:/Users/John Xu/Desktop/NYC_Taxi_Trips/data/Data/Green Taxi Data 2019-6.csv']

# %%
Green_taxi_data_list = [pd.read_csv(path) for path in directory_list]
Green_taxi_data = pd.concat(Green_taxi_data_list, axis=0, ignore_index=True)

# %%
Green_taxi_data.columns
# Out:
# Index(['Unnamed: 0', 'VendorID', 'lpep_pickup_datetime',
#        'lpep_dropoff_datetime', 'store_and_fwd_flag', 'RatecodeID',
#        'PULocationID', 'DOLocationID', 'passenger_count', 'trip_distance',
#        'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'ehail_fee', 'improvement_surcharge', 'total_amount', 'payment_type',
#        'trip_type', 'congestion_surcharge'],
#       dtype='object')

# %%
Green_taxi_data.drop(['Unnamed: 0'], axis=1)
# Out:
#          VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0               2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1               2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2               2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3               2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4               2  2019-01-01 00:19:06   2019-01-01 00:39:43
# 5               2  2019-01-01 00:12:35   2019-01-01 00:19:09
# 6               2  2019-01-01 00:47:55   2019-01-01 01:00:01
# 7               1  2019-01-01 00:12:47   2019-01-01 00:30:50
# 8               2  2019-01-01 00:16:23   2019-01-01 00:39:46
# 9               2  2019-01-01 00:58:02   2019-01-01 01:19:02
# 10              2  2019-01-01 00:37:00   2019-01-01 00:56:42
# 11              2  2019-01-01 00:13:48   2019-01-01 00:21:00
# 12              2  2019-01-01 00:19:59   2019-01-01 00:45:50
# 13              2  2019-01-01 00:57:57   2019-01-01 01:20:10
# ...
